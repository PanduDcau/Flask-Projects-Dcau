# %% [markdown]
# # WINE QUALITY PREDICTION
#
# The code is an example of how to apply machine learning to wine quality prediction
#
# <img src="wine.jpeg">

# %% [markdown]
# ## STEP 1 : IMPORTING THE DATASET

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("wine_fraud.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
sns.countplot(x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %% [markdown]
# ## STEP 2 : PREPROCESSING THE DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   object
#  12  type                  6497 non-null   object
# dtypes: float64(11), object(2)
# memory usage: 660.0+ KB

# %%
df['quality'] = df['quality'].map({'Legit': 0, 'Fraud': 1}).astype('float64')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4      0.0  red
# 1      9.8      0.0  red
# ...

# %%
df['type'] = df['type'].map({'red': 0, 'white': 1}).astype('float64')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  type
# 0      9.4      0.0   0.0
# 1      9.8      0.0   0.0
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                    0.021794          0.151228    -0.061789
# type                      -0.486740         -0.653036     0.187397
#
# ...

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# quality                 1.000000
# type                   -0.004598
# Name: quality, dtype: float64

# %%
df.corr()['quality'][:-2].sort_values().plot(kind='bar', fontsize=9)
# Out:
# <Axes: >

# %% [markdown]
# ## STEP 3 : TRAIN TEST SPLIT

# %%
X = df.drop('quality',axis=1)
y = df['quality']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# ## STEP 4 : TRAIN THE MACHINE LEARNING MODEL

# %%
from sklearn.svm import SVC

# %%
svc = SVC(class_weight='balanced')

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],'gamma':[0.001,0.01,0.1,0.5,1]}
grid = GridSearchCV(svc,param_grid)

# %%
grid.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': [0.001, 0.01, 0.1, 0.5, 1]})

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 1}

# %% [markdown]
# ## STEP 5 : TESTING THE MACHINE LEARNING MODEL

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
grid_pred = grid.predict(scaled_X_test)

# %%
confusion_matrix(y_test,grid_pred)
# Out:
# array([[619,   4],
#        [ 23,   4]])

# %%
print(classification_report(y_test,grid_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98       623
#          1.0       0.50      0.15      0.23        27
#
#     accuracy                           0.96       650
#    macro avg       0.73      0.57      0.60       650
# weighted avg       0.94      0.96      0.95       650
