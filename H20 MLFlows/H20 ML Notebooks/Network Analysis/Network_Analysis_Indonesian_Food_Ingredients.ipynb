# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
df_raw = pd.read_csv("/content/Network Analysis_query3.csv", index_col=None, header=0)

# %%
df = pd.DataFrame()
df['food'] = df_raw['food']
df['food_name'] = df_raw['foodLabel']
df['ingredient_id'] = df_raw['mother']
df['ingredient_name'] = df_raw['label_clean']
df['origin_id'] = df_raw['father']
df['origin_name'] = df_raw['fatherLabel']
df['ingredient_category'] = df_raw['category']
df
# Out:
#                                            food  ... ingredient_category
# 0     http://www.wikidata.org/entity/Q100255672  ...               spice
# 1     http://www.wikidata.org/entity/Q100255672  ...              fruits
# 2     http://www.wikidata.org/entity/Q100255672  ...               flour
# 3     http://www.wikidata.org/entity/Q100255672  ...               flour
# 4     http://www.wikidata.org/entity/Q100529246  ...               spice
# ...                                         ...  ...                 ...
# 2336      http://www.wikidata.org/entity/Q59602  ...                 NaN
# 2337      http://www.wikidata.org/entity/Q59602  ...                 NaN
# 2338      http://www.wikidata.org/entity/Q59602  ...                 NaN
# 2339      http://www.wikidata.org/entity/Q59602  ...                 NaN
# 2340      http://www.wikidata.org/entity/Q59602  ...                 NaN
#
# [2341 rows x 7 columns]

# %%
import sqlite3 as sl

# %%
con = sl.connect('test_db.db')

# %%
with con:
    con.execute("""
        CREATE TABLE IF NOT EXISTS FOOD_INGREDIENT (
            food TEXT NOT NULL,
            food_name TEXT,
            ingredient_id TEXT,
            ingredient_name TEXT,
            origin_id TEXT,
            origin_name TEXT,
            ingredient_category TEXT
        );
    """)

# %%
data = df.values.tolist()

# %%
sql = 'INSERT INTO FOOD_INGREDIENT (food, food_name, ingredient_id, ingredient_name, origin_id, origin_name, ingredient_category) values(?, ?, ?, ?, ?, ?, ?)'

# %%
with con:
    con.executemany(sql, data)

# %%
with con:
    data = con.execute("SELECT * FROM FOOD_INGREDIENT WHERE food_name = 'cenil'")
    for row in data:
        print(row)
# Out:
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11002', 'sugar', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11254', 'salt', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q177998', 'agar', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q753009', 'food coloring', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'misc')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q841779', 'coconut milk', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q3342808', 'coconut', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q43304555', 'cassava', 'http://www.wikidata.org/entity/Q3557', 'Central Java', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11002', 'sugar', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11254', 'salt', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q177998', 'agar', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q753009', 'food coloring', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'misc')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q841779', 'coconut milk', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q3342808', 'coconut', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q43304555', 'cassava', 'http://www.wikidata.org/entity/Q3586', 'East Java', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11002', 'sugar', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11254', 'salt', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q177998', 'agar', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q753009', 'food coloring', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'misc')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q841779', 'coconut milk', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q3342808', 'coconut', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q43304555', 'cassava', 'http://www.wikidata.org/entity/Q10674', 'Purworejo', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11002', 'sugar', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11254', 'salt', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q177998', 'agar', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q753009', 'food coloring', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'misc')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q841779', 'coconut milk', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q3342808', 'coconut', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q43304555', 'cassava', 'http://www.wikidata.org/entity/Q11111', 'Pacitan', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11002', 'sugar', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q11254', 'salt', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'spice')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q177998', 'agar', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'carb')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q753009', 'food coloring', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'misc')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q841779', 'coconut milk', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q3342808', 'coconut', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'fruits')
# ('http://www.wikidata.org/entity/Q11114189', 'cenil', 'http://www.wikidata.org/entity/Q43304555', 'cassava', 'http://www.wikidata.org/entity/Q11443', 'Kediri', 'carb')

# %%
df = pd.read_sql_query("SELECT food_name, group_concat(replace(ingredient_name,' ','_'), ' ') as ingredient_list from (select distinct food_name, ingredient_name from FOOD_INGREDIENT) group by 1", con)
df = df.dropna()
df
# Out:
#                 food_name                                    ingredient_list
# 1          Adon-Adon Coro               ginger spice coconut_milk palm_sugar
# 2                  Angsle                        glutinous_rice coconut_milk
# 6    Ayam panggang Bangka                                            chicken
# 7      Babi Panggang Karo                                          pork_meat
# 8                Babungku  salt coconut_milk rice_flour banana_leaf brown...
# ..                    ...                                                ...
# 408                 tiwul                                            cassava
# 409               tumpeng                                    rice egg tempeh
# 411                  urap  white_cabbage spinach asparagus bean_sprout co...
# 414                wingko  margarine sugar salt coconut glutinous_rice_flour
# 415                yangko                   water sugar glutinous_rice_flour
#
# [236 rows x 2 columns]

# %%
# df.to_csv("Downloads/query_food.csv")
total_ingredient = pd.read_sql_query("SELECT ingredient_name, ingredient_category, count(distinct food_name) from FOOD_INGREDIENT where ingredient_name is not null group by 1,2 order by 3 desc", con)
total_ingredient
# Out:
#     ingredient_name ingredient_category  count(distinct food_name)
# 0      coconut milk              fruits                         63
# 1              salt               spice                         59
# 2             sugar               spice                         44
# 3            garlic               spice                         35
# 4        palm sugar           seasoning                         34
# ..              ...                 ...                        ...
# 187          turnip               spice                          1
# 188       vegetable          vegetables                          1
# 189          walnut                nuts                          1
# 190   white cabbage          vegetables                          1
# 191            yolk       dairy and egg                          1
#
# [192 rows x 3 columns]

# %% [markdown]
# # Create Ingredient Connection

# %%
# Create a sublist of lower case words for each tweet
ingredient_in_list = [ingredient.split() for ingredient in df.ingredient_list]

# %%
import nltk
from nltk import bigrams

# Create list of lists containing bigrams in tweets
terms_bigram = [list(bigrams(tweet)) for tweet in ingredient_in_list]

# View bigrams for the first tweet
terms_bigram[0]
# Out:
# [('ginger', 'spice'),
#  ('spice', 'coconut_milk'),
#  ('coconut_milk', 'palm_sugar')]

# %%
import itertools
import collections

# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

bigram_counts.most_common(20)
# Out:
# [(('sugar', 'salt'), 22),
#  (('coconut_milk', 'rice_flour'), 13),
#  (('glutinous_rice', 'coconut_milk'), 7),
#  (('rice_flour', 'wheat_flour'), 7),
#  (('pandan', 'coconut_milk'), 7),
#  (('coconut_milk', 'palm_sugar'), 6),
#  (('salt', 'coconut_milk'), 6),
#  (('sugar', 'coconut_milk'), 6),
#  (('palm_sugar', 'coconut'), 6),
#  (('palm_sugar', 'cassava'), 6),
#  (('salt', 'chili'), 5),
#  (('salt', 'garlic'), 5),
#  (('rice_flour', 'coconut'), 5),
#  (('water', 'salt'), 5),
#  (('sugar', 'glutinous_rice'), 4),
#  (('coconut_milk', 'glutinous_rice_flour'), 4),
#  (('coconut', 'glutinous_rice_flour'), 4),
#  (('onion', 'garlic'), 4),
#  (('flour', 'egg'), 4),
#  (('egg', 'coconut_milk'), 4)]

# %%
from collections import defaultdict

def co_occurrence(sentences, window_size):
    d = defaultdict(int)
    vocab = set()
    for text in sentences:
        # preprocessing
        text = text.lower().split()
        # iterate over ingredient list
        for i in range(len(text)):
            token = text[i]
            vocab.add(token)  # add to vocab
            next_token = text[i+1 : i+1+window_size]
            for t in next_token:
                key = tuple( sorted([t, token]) )
                d[key] += 1
    
    # formulate the dictionary into dataframe
    vocab = sorted(vocab) # sort vocab
    df = pd.DataFrame(data=np.zeros((len(vocab), len(vocab)), dtype=np.int16),
                      index=vocab,
                      columns=vocab)
    for key, value in d.items():
        df.at[key[0], key[1]] = value
        df.at[key[1], key[0]] = value
    return df

# %%
df_test = co_occurrence(df.ingredient_list, 2)
df_test
# Out:
#                agar  amaranth  ambarella  ...  white_cabbage  yeast  yolk
# agar              0         0          0  ...              0      0     0
# amaranth          0         0          0  ...              0      0     0
# ambarella         0         0          0  ...              0      0     0
# anchovy           0         0          0  ...              0      0     0
# arrow_loach       0         0          0  ...              0      0     0
# ...             ...       ...        ...  ...            ...    ...   ...
# water             0         0          0  ...              0      0     0
# wheat_flour       0         0          0  ...              0      4     1
# white_cabbage     0         0          0  ...              0      0     0
# yeast             0         0          0  ...              0      0     1
# yolk              0         0          0  ...              0      1     0
#
# [190 rows x 190 columns]

# %%
df_temp = df_test.head(20)

# %%
columns = list(df_temp)
columns
# Out:
# ['agar',
#  'amaranth',
#  'ambarella',
#  'anchovy',
#  'arrow_loach',
#  'asam',
#  'asparagus',
#  'baking_powder',
#  'bamboo',
#  'bamboo_shoots',
#  'banana',
#  'banana_leaf',
#  'basil',
#  'bay_leaf',
#  'bean_sprout',
#  'beef',
#  'beet',
#  'bell_fruit',
#  'bilimbi',
#  'black-eyed_pea',
#  'blackpepper',
#  'bottlegourd',
#  'bread',
#  'breadnut',
#  'broth',
#  'brown_sugar',
#  'butter',
#  'cabbage',
#  'candlenut',
#  'cardamom',
#  'carrot',
#  'cassava',
#  'cassava_flour',
#  'cattle',
#  'cauliflower',
#  'celery',
#  'cendol',
#  'chicken',
#  'chicken_fingers',
#  'chicken_stock',
#  'chili',
#  'chives',
#  'chocolate_powder',
#  'cinnamon',
#  'clam',
#  'coconut',
#  'coconut_cream',
#  'coconut_milk',
#  'coconut_oil',
#  'coffee_bean',
#  'condiment',
#  'cooking_oil',
#  'coriander',
#  'corn',
#  "cow's_trotters",
#  'cowhide',
#  'cracker',
#  'cucumber',
#  'dried_shrimp',
#  'drinking_water',
#  'duck_meat',
#  'egg',
#  'egg_white',
#  'eggplant',
#  'emping',
#  'fish',
#  'flavour_enhancer',
#  'flour',
#  'food_coloring',
#  'fried_onion',
#  'galangal',
#  'garlic',
#  'ghost_pepper',
#  'ginger',
#  'glutinous_rice',
#  'glutinous_rice_flour',
#  'gowok',
#  'grass_jelly',
#  'green_bean',
#  'herb',
#  'honey',
#  'hot_sauce',
#  'ice',
#  'innards',
#  'intestine',
#  'iridescent_shark',
#  'jackfruit',
#  'jengkol',
#  'jicama',
#  'kaffir_lime',
#  'kecombrang',
#  'keluak',
#  'ketupat',
#  'kidney_bean',
#  'krupuk',
#  'lamb',
#  'lemon',
#  'lemongrass',
#  'lime',
#  'lontong',
#  'mackerel',
#  'mango',
#  'margarine',
#  'meat',
#  'melinjo',
#  'milk',
#  'milkfish',
#  'minced_meat',
#  'mineral_water',
#  'msg',
#  'mung_bean_sprout',
#  'mungbean',
#  'mushroom',
#  'noodle',
#  'nutmeg',
#  'offal',
#  'oil',
#  'oncom',
#  'onion',
#  'palm_oil',
#  'palm_sugar',
#  'pandan',
#  'papaya',
#  'papaya_leaf',
#  'peanut',
#  'pepper',
#  'pig',
#  'pineapple',
#  'plantain',
#  'pork_meat',
#  'potato',
#  'rabbit_meat',
#  'ragout',
#  'red_onion',
#  'rice',
#  'rice_cake',
#  'rice_flour',
#  'rice_vermicelli',
#  'saba_banana',
#  'sago',
#  'sago_flour',
#  'salak',
#  'salt',
#  'satay_sauce',
#  'sausage',
#  'scallion',
#  'seaweed',
#  'shallot',
#  'shrimp',
#  'shrimp_or_prawn',
#  'shrimp_paste',
#  'skipjack_tuna',
#  'snail',
#  'snakehead_fish',
#  'sodium_bicarbonate',
#  'soy_bean',
#  'soy_sauce',
#  'spice',
#  'spinach',
#  'squash',
#  'squid',
#  'star_anise',
#  'stick',
#  'sugar',
#  'sugarcane',
#  'sweet_potato',
#  'tamarind',
#  'tapai',
#  'tapioca',
#  'tapioca_flour',
#  'tauco',
#  'teak',
#  'tempeh',
#  'tilia_leaf',
#  'tofu',
#  'tomato',
#  'tripe',
#  'tuna',
#  'turmeric',
#  'turnip',
#  'vanilla',
#  'vegetable',
#  'vegetable_oil',
#  'vinegar',
#  'walnut',
#  'water',
#  'wheat_flour',
#  'white_cabbage',
#  'yeast',
#  'yolk']

# %%
df_compiled = pd.DataFrame(columns=['bigram','count'])

for i,row in df_test.iterrows():
    for j in columns:
        if row[j] > 0:
            bigram_name = (i,j)
            reverse_bigram_name = (j,i)
            bigram_value = row[j]
            df_t = pd.DataFrame(columns=['bigram','count'])
            df_t.loc[-1] = [bigram_name, bigram_value]
            if df_compiled[df_compiled['bigram']==reverse_bigram_name].empty == False:
                print('dup')
            else:
                df_compiled = df_compiled.append(df_t, ignore_index = True)
# Out:
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup
# dup

# %%
df_compiled
# Out:
#                            bigram count
# 0            (agar, coconut_milk)     1
# 1           (agar, food_coloring)     1
# 2                    (agar, salt)     1
# 3                   (agar, sugar)     1
# 4               (amaranth, basil)     1
# ..                            ...   ...
# 830        (tilia_leaf, turmeric)     2
# 831  (vegetable_oil, wheat_flour)     1
# 832          (wheat_flour, yeast)     4
# 833           (wheat_flour, yolk)     1
# 834                 (yeast, yolk)     1
#
# [835 rows x 2 columns]

# %%
df_compiled = df_compiled.sort_values(by=['count'], ascending=False)
df_compiled
# Out:
#                                        bigram count
# 778                             (salt, sugar)    22
# 361                      (coconut_milk, salt)    15
# 358                (coconut_milk, rice_flour)    15
# 366                     (coconut_milk, sugar)    13
# 335            (coconut_milk, glutinous_rice)    11
# ..                                        ...   ...
# 296                         (chives, tapioca)     1
# 297                            (chives, tofu)     1
# 298  (chocolate_powder, glutinous_rice_flour)     1
# 299           (chocolate_powder, wheat_flour)     1
# 834                             (yeast, yolk)     1
#
# [835 rows x 2 columns]

# %% [markdown]
# # Create Graph

# %%
import networkx as nx

# %%
# Create dictionary of edges and their weights
d = df_compiled.head(100).set_index('bigram').T.to_dict('records')

# %%
d
# Out:
# [{('asparagus', 'bean_sprout'): 3,
#   ('banana', 'sugar'): 3,
#   ('bay_leaf', 'lemongrass'): 3,
#   ('beef', 'galangal'): 5,
#   ('beef', 'ginger'): 3,
#   ('beef', 'lemongrass'): 3,
#   ('beef', 'scallion'): 3,
#   ('blackpepper', 'salt'): 2,
#   ('brown_sugar', 'coconut'): 3,
#   ('brown_sugar', 'coconut_milk'): 5,
#   ('brown_sugar', 'glutinous_rice_flour'): 2,
#   ('brown_sugar', 'rice_flour'): 6,
#   ('butter', 'egg'): 3,
#   ('cassava', 'coconut'): 3,
#   ('cassava', 'palm_sugar'): 6,
#   ('chicken', 'coconut_milk'): 2,
#   ('chicken', 'egg'): 2,
#   ('chicken', 'garlic'): 2,
#   ('chicken', 'onion'): 3,
#   ('chicken', 'spinach'): 2,
#   ('chili', 'coconut_milk'): 3,
#   ('chili', 'galangal'): 3,
#   ('chili', 'meat'): 3,
#   ('chili', 'salt'): 6,
#   ('chili', 'shallot'): 3,
#   ('chili', 'turmeric'): 3,
#   ('coconut', 'coconut_milk'): 6,
#   ('coconut', 'ginger'): 2,
#   ('coconut', 'glutinous_rice'): 3,
#   ('coconut', 'glutinous_rice_flour'): 4,
#   ('coconut', 'palm_sugar'): 6,
#   ('coconut', 'pandan'): 2,
#   ('coconut', 'rice_flour'): 5,
#   ('coconut', 'salt'): 3,
#   ('coconut', 'sugar'): 4,
#   ('coconut_milk', 'egg'): 8,
#   ('coconut_milk', 'ginger'): 3,
#   ('coconut_milk', 'glutinous_rice'): 11,
#   ('coconut_milk', 'glutinous_rice_flour'): 7,
#   ('coconut_milk', 'lamb'): 3,
#   ('coconut_milk', 'mackerel'): 3,
#   ('coconut_milk', 'palm_sugar'): 8,
#   ('coconut_milk', 'pandan'): 7,
#   ('coconut_milk', 'rice'): 2,
#   ('coconut_milk', 'rice_flour'): 15,
#   ('coconut_milk', 'salt'): 15,
#   ('coconut_milk', 'shallot'): 3,
#   ('coconut_milk', 'spice'): 2,
#   ('coconut_milk', 'sugar'): 13,
#   ('coconut_milk', 'tofu'): 2,
#   ('coconut_milk', 'wheat_flour'): 7,
#   ('coconut_milk', 'yeast'): 3,
#   ('egg', 'flour'): 5,
#   ('egg', 'garlic'): 4,
#   ('egg', 'salt'): 7,
#   ('egg', 'sugar'): 3,
#   ('egg', 'tofu'): 3,
#   ('egg', 'wheat_flour'): 4,
#   ('flour', 'salt'): 3,
#   ('galangal', 'garlic'): 3,
#   ('galangal', 'lemongrass'): 3,
#   ('galangal', 'shallot'): 4,
#   ('garlic', 'ginger'): 5,
#   ('garlic', 'onion'): 8,
#   ('garlic', 'salt'): 8,
#   ('garlic', 'sugar'): 2,
#   ('garlic', 'tilia_leaf'): 2,
#   ('garlic', 'tofu'): 2,
#   ('garlic', 'tomato'): 4,
#   ('garlic', 'turmeric'): 3,
#   ('garlic', 'water'): 2,
#   ('ginger', 'lemongrass'): 5,
#   ('ginger', 'turmeric'): 3,
#   ('glutinous_rice', 'palm_sugar'): 5,
#   ('glutinous_rice', 'pandan'): 3,
#   ('glutinous_rice', 'salt'): 4,
#   ('glutinous_rice', 'sugar'): 7,
#   ('glutinous_rice_flour', 'palm_sugar'): 4,
#   ('glutinous_rice_flour', 'salt'): 5,
#   ('glutinous_rice_flour', 'sugar'): 3,
#   ('lemongrass', 'turmeric'): 2,
#   ('lime', 'salt'): 2,
#   ('margarine', 'sugar'): 2,
#   ('palm_oil', 'salt'): 3,
#   ('palm_sugar', 'pandan'): 3,
#   ('palm_sugar', 'peanut'): 2,
#   ('palm_sugar', 'rice_flour'): 3,
#   ('palm_sugar', 'salt'): 3,
#   ('palm_sugar', 'sugar'): 4,
#   ('pandan', 'rice_flour'): 3,
#   ('rice', 'salt'): 3,
#   ('rice_flour', 'salt'): 5,
#   ('rice_flour', 'sugar'): 6,
#   ('rice_flour', 'wheat_flour'): 8,
#   ('salt', 'shallot'): 3,
#   ('salt', 'soy_sauce'): 4,
#   ('salt', 'sugar'): 22,
#   ('salt', 'water'): 7,
#   ('sugar', 'water'): 4,
#   ('wheat_flour', 'yeast'): 4}]

# %%
# Create network plot 
G = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v * 10))

# %%
G

# %% [markdown]
# ## All Ingredients Graph

# %%
fig, ax = plt.subplots(figsize=(16, 12))

pos = nx.spring_layout(G, k=2)

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=8,
                 width=3,
                 edge_color='grey',
                 node_color='#00b4d9',
                 with_labels = True,
                 ax=ax)

plt.show()

# %%
weights = nx.get_edge_attributes(G,'weight').values()
weights
# Out:
# dict_values([220, 150, 80, 70, 70, 60, 50, 50, 40, 40, 30, 30, 30, 30, 30, 30, 20, 20, 130, 70, 60, 40, 40, 40, 30, 30, 30, 20, 20, 150, 110, 80, 80, 70, 70, 70, 60, 50, 30, 30, 30, 30, 30, 30, 20, 20, 20, 20, 80, 60, 50, 30, 30, 50, 30, 30, 80, 50, 40, 40, 30, 30, 20, 20, 20, 20, 60, 60, 40, 30, 20, 40, 40, 50, 30, 30, 20, 30, 40, 20, 20, 30, 30, 20, 30, 30, 30, 30, 50, 30, 30, 30, 30, 30, 20, 50, 30, 40, 30, 20])

# %% [markdown]
# ## Modify Graph

# %%
# Use node degree as the node size

fig, ax = plt.subplots(figsize=(16, 12))

pos = nx.spring_layout(G, k=2)

d = dict(G.degree)

nx.draw(G, pos,
        font_size=8,
        width=1,
        edge_color='grey',
        node_color='#00b4d9',
        with_labels = True, 
        nodelist=d.keys(), 
        node_size=[v * 12 for v in d.values()])
plt.show()

# %%
carac = pd.DataFrame()
carac = total_ingredient[['ingredient_name','ingredient_category']]
carac
# Out:
#     ingredient_name ingredient_category
# 0      coconut milk              fruits
# 1              salt               spice
# 2             sugar               spice
# 3            garlic               spice
# 4        palm sugar           seasoning
# ..              ...                 ...
# 187          turnip               spice
# 188       vegetable          vegetables
# 189          walnut                nuts
# 190   white cabbage          vegetables
# 191            yolk       dairy and egg
#
# [192 rows x 2 columns]

# %%
import matplotlib

d = df_compiled.head(100).set_index('bigram').T.to_dict('records')

# Create network plot 
G_mod = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G_mod.add_edge(k[0], k[1], weight=(v * 10))

# Get the dataframe of ingredient name and it's category    
carac = pd.DataFrame()
carac = total_ingredient[['ingredient_name','ingredient_category']]

# Reindex the dataframe to align with graph's nodes
carac = carac.set_index('ingredient_name')
carac = carac.reindex(G_mod.nodes())

carac['ingredient_category'] = pd.Categorical(carac['ingredient_category'])
carac['ingredient_category'].cat.codes

# Specify colors, number of colors listed should align with the number of categories
cmap = matplotlib.colors.ListedColormap(['C0', 'darkorange', 'lightgreen', 'lightyellow', 'darkgreen', 'darkblue', 'purple', 'red', 'pink', 'brown'])

# Get node degree in a dict for node size parameter
d = dict(G.degree)

# Draw graph
fig, ax = plt.subplots(figsize=(16, 12))

pos = nx.spring_layout(G, k=2)

nx.draw(G, pos,
        font_size=10,
        width=1,
        edge_color='grey',
        node_color=carac['ingredient_category'].cat.codes, 
        cmap=cmap,
        with_labels = True, 
        nodelist=d.keys(), 
        node_size=[v * 12 for v in d.values()])
plt.show()

# %%
# Compute the degree centralities of G: deg_cent
deg_cent = nx.degree_centrality(G)

# Compute the maximum degree centrality: max_dc
max_dc = max(deg_cent.values())

# Find the item(s) that have highest co-occurrence: prolific_collaborators
prolific_collaborators = [n for n, dc in deg_cent.items() if dc == max_dc]

print(prolific_collaborators)
# Out:
# ['coconut_milk']

# %% [markdown]
# ## Subset Cliques

# %%
list(nx.find_cliques(G))
# Out:
# [['tilia_leaf', 'garlic'],
#  ['turmeric', 'chili'],
#  ['turmeric', 'ginger', 'lemongrass'],
#  ['turmeric', 'ginger', 'garlic'],
#  ['galangal', 'shallot', 'chili'],
#  ['galangal', 'lemongrass', 'beef'],
#  ['galangal', 'garlic'],
#  ['asparagus', 'bean_sprout'],
#  ['peanut', 'palm_sugar'],
#  ['soy_sauce', 'salt'],
#  ['blackpepper', 'salt'],
#  ['spinach', 'chicken'],
#  ['cassava', 'palm_sugar', 'coconut'],
#  ['coconut_milk', 'pandan', 'palm_sugar', 'coconut', 'rice_flour'],
#  ['coconut_milk', 'pandan', 'palm_sugar', 'coconut', 'glutinous_rice'],
#  ['coconut_milk', 'salt', 'sugar', 'coconut', 'palm_sugar', 'rice_flour'],
#  ['coconut_milk',
#   'salt',
#   'sugar',
#   'coconut',
#   'palm_sugar',
#   'glutinous_rice_flour'],
#  ['coconut_milk', 'salt', 'sugar', 'coconut', 'palm_sugar', 'glutinous_rice'],
#  ['coconut_milk', 'salt', 'sugar', 'egg'],
#  ['coconut_milk', 'salt', 'shallot', 'chili'],
#  ['coconut_milk', 'salt', 'rice'],
#  ['coconut_milk', 'yeast', 'wheat_flour'],
#  ['coconut_milk', 'lamb'],
#  ['coconut_milk', 'tofu', 'egg'],
#  ['coconut_milk', 'brown_sugar', 'coconut', 'rice_flour'],
#  ['coconut_milk', 'brown_sugar', 'coconut', 'glutinous_rice_flour'],
#  ['coconut_milk', 'chicken', 'egg'],
#  ['coconut_milk', 'wheat_flour', 'rice_flour'],
#  ['coconut_milk', 'wheat_flour', 'egg'],
#  ['coconut_milk', 'mackerel'],
#  ['coconut_milk', 'spice'],
#  ['coconut_milk', 'ginger', 'coconut'],
#  ['banana', 'sugar'],
#  ['lemongrass', 'bay_leaf'],
#  ['lemongrass', 'beef', 'ginger'],
#  ['beef', 'scallion'],
#  ['margarine', 'sugar'],
#  ['butter', 'egg'],
#  ['meat', 'chili'],
#  ['tomato', 'garlic'],
#  ['onion', 'chicken', 'garlic'],
#  ['garlic', 'water', 'salt', 'sugar'],
#  ['garlic', 'egg', 'salt', 'sugar'],
#  ['garlic', 'egg', 'tofu'],
#  ['garlic', 'egg', 'chicken'],
#  ['palm_oil', 'salt'],
#  ['lime', 'salt'],
#  ['flour', 'salt', 'egg']]

# %%
# Define get_nodes_and_nbrs()
def get_nodes_and_nbrs(G, nodes_of_interest):
    """
    Returns a subgraph of the graph `G` with only the `nodes_of_interest` and their neighbors.
    """
    nodes_to_draw = []

    # Iterate over the nodes of interest
    for n in nodes_of_interest:

        # Append the nodes of interest to nodes_to_draw
        nodes_to_draw.append(n)

        # Iterate over all the neighbors of node n
        for nbr in G.neighbors(n):

            # Append the neighbors of n to nodes_to_draw
            nodes_to_draw.append(nbr)

    return G.subgraph(nodes_to_draw)

# %%
# Extract the subgraph with the nodes of interest: T_draw
T_draw = get_nodes_and_nbrs(G, ['coconut_milk'])

# Draw the subgraph to the screen
nx.draw(T_draw, with_labels=True)
plt.show()

# %%
# Extract the subgraph with the nodes of interest: T_draw
T_draw = get_nodes_and_nbrs(G, ['palm_sugar'])

# Draw the subgraph to the screen
nx.draw(T_draw, with_labels=True)
plt.show()

# %%
# Extract the subgraph with the nodes of interest: T_draw
T_draw = get_nodes_and_nbrs(G, ['lemongrass'])

# Draw the subgraph to the screen
nx.draw(T_draw, with_labels=True)
plt.show()
